# %% [markdown]
# # Retrieval Augmented Generation (RAG) with OpenAI and Qdrant

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Setting up all the pieces to implement the RAG pipeline using Qdrant and OpenAI SDKs

# %%
# !pip install qdrant-client fastembed openai
# Out:
# Collecting qdrant-client
#   Downloading qdrant_client-1.7.0-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 3.9 MB/s eta 0:00:00
# Collecting fastembed
#   Downloading fastembed-0.1.1-py3-none-any.whl (14 kB)
# Collecting openai
#   Downloading openai-1.3.8-py3-none-any.whl (221 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.59.3)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client)
#   Downloading grpcio_tools-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 48.0 MB/s eta 0:00:00
# Collecting httpx[http2]>=0.14.0 (from qdrant-client)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.23.5)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.10.13)
# Collecting urllib3<2.0.0,>=1.26.14 (from qdrant-client)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 16.2 MB/s eta 0:00:00
# Collecting onnx<2.0,>=1.11 (from fastembed)
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 61.7 MB/s eta 0:00:00
# Collecting onnxruntime<2.0,>=1.15 (from fastembed)
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 66.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.10/dist-packages (from fastembed) (2.31.0)
# Collecting tokenizers<0.14,>=0.13 (from fastembed)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0,>=4.65 in /usr/local/lib/python3.10/dist-packages (from fastembed) (4.66.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai) (4.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Collecting protobuf<5.0dev,>=4.21.6 (from grpcio-tools>=1.41.0->qdrant-client)
#   Downloading protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 29.8 MB/s eta 0:00:00
# Collecting grpcio>=1.41.0 (from qdrant-client)
#   Downloading grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 90.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (67.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant-client) (2023.11.17)
# Collecting httpcore==1.* (from httpx[http2]>=0.14.0->qdrant-client)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx[http2]>=0.14.0->qdrant-client)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# Collecting h2<5,>=3 (from httpx[http2]>=0.14.0->qdrant-client)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.7 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime<2.0,>=1.15->fastembed)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.15->fastembed) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.15->fastembed) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2.0,>=1.15->fastembed) (1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.31->fastembed) (3.3.2)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2.0,>=1.15->fastembed)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2.0,>=1.15->fastembed) (1.3.0)
# Installing collected packages: tokenizers, urllib3, protobuf, portalocker, hyperframe, humanfriendly, hpack, h11, grpcio, onnx, httpcore, h2, grpcio-tools, coloredlogs, onnxruntime, httpx, openai, fastembed, qdrant-client
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.59.3
#     Uninstalling grpcio-1.59.3:
#       Successfully uninstalled grpcio-1.59.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.1 which is incompatible.
# transformers 4.35.2 requires tokenizers<0.19,>=0.14, but you have tokenizers 0.13.3 which is incompatible.
# Successfully installed coloredlogs-15.0.1 fastembed-0.1.1 grpcio-1.60.0 grpcio-tools-1.60.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.2 httpx-0.25.2 humanfriendly-10.0 hyperframe-6.0.1 onnx-1.15.0 onnxruntime-1.16.3 openai-1.3.8 portalocker-2.8.2 protobuf-4.25.1 qdrant-client-1.7.0 tokenizers-0.13.3 urllib3-1.26.18

# %% [markdown]
# Qdrant will act as a knowledge base providing the context information for the prompts we'll be sending to the LLM. There are various ways of running Qdrant, but we'll simply use the Docker container.
#
# Qdrant collection is the basic unit of organizing your data. Each collection is a named set of points (vectors with a payload) among which you can search. After connecting to our running Qdrant container, we can check whether we already have some collections.

# %%
from qdrant_client import QdrantClient
client = QdrantClient(":memory:")
client.get_collections()
# Out:
# CollectionsResponse(collections=[])

# %% [markdown]
# ### Building the knowledge base

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/datasets/WebMining/drugdata.csv")
df.head()
# Out:
#   drug_name review_source                                        drug_review  \
# 0    Elidel     Drugs.com  no! no! no! do not use Elidel it's worse than ...
# 1    Elidel     Drugs.com  I've been so interested to find out what other...
# 2    Elidel     Drugs.com  After being prescribed Elidel, my skin got muc...
# 3    Elidel     Drugs.com  After having eczema most of my life, it seemed...
# 4    Elidel     Drugs.com  I never leave reviews for anything, but knowin...
#
#                                               tokens  concreteness  \
# 0  ['use', 'elidel', 'bad', 'hydrocortisone', 'ta...      0.365854
# 1  ['interested', 'find', 'think', 'elidel', 'suf...      0.080000
# 2  ['prescribe', 'elidel', 'skin', 'get', 'bad', ...      0.257143
# 3  ['have', 'eczema', 'life', 'bad', 'have', 'all...      0.258427
# 4  ['leave', 'review', ' ', 'know', 'like', 'come...      0.135135
#
#              modality sentiments disease  \
# 0    Deontic modality   Negative  Eczema
# 1  Epistemic modality   Negative  Eczema
# 2    Deontic modality   Negative  Eczema
# 3    Deontic modality    Neutral  Eczema
# 4  Uncertain modality   Positive  Eczema
#
#                                         side effects side effects grouped  \
# 0                         Topical Steroid Withdrawal             Flu-like
# 1                         Topical Steroid Withdrawal             Flu-like
# 2  Topical Steroid Withdrawal, Weakened Immunity ...             Flu-like
# 3                    Weakened Immune System, Fatigue             Flu-like
# 4                                                Nil                  Nil
#
#                                 side effects cleaned  \
# 0                         Topical Steroid Withdrawal
# 1                         Topical Steroid Withdrawal
# 2  Topical Steroid Withdrawal, Weakened Immune Sy...
# 3                    Weakened Immune System, Fatigue
# 4                                                Nil
#
#   side_effects_cleaned_grouped
# 0                 Skin-Related
# 1                 Skin-Related
# 2         Skin-Related,General
# 3        General,Psychological
# 4                          Nil

# %%
reviews = ["I was diagnosed with " + str(row.disease) + ". The doctor prescribed me " + str(row.drug_name) + ". " + "Review: " + str(row.drug_review) for row in df.itertuples()]
reviews[0]
# Out:
# "I was diagnosed with Eczema. The doctor prescribed me Elidel. Review: no! no! no! do not use Elidel it's worse than using hydrocortisone. It took me over a year for my face to clear up which is where my doctor told me to apply it on. Big mistake. Please note that prolonged use of any topical treatment for eczema such as topical steroids and even immunosuppressants like Elidel can lead to developing Topical Steroid Withdrawal/topical steroid withdrawal. if you feel your eczema is getting worse and worse please look up topical steroid withdrawal!"

# %%
client.add(
    collection_name="knowledge-base",
    documents=reviews
)
# Out:
# 100%|██████████| 77.7M/77.7M [00:03<00:00, 20.8MiB/s]
# ['d3432b85dda64cb3ac93e1f58d66fa23',
#  '18ec4b8d4c3a4773b5153f8d47acfc9f',
#  '9957b10fa0f94ba3b37eda2ed9b8d547',
#  '49fe1398994f49efa44607e525a6c889',
#  '34572e49e1264a0ba9a1bec8644f9b16',
#  '5bac72003f884a11bb572d5954f61fb2',
#  '8b85c9d95d4a40aea59c84646b1f1a86',
#  'f205c97bf6db4e97bb8732110f193e93',
#  '25b691528eb743a4a10da20d849184ef',
#  '79eb68a75bdc40cca797127cc42b754a',
#  '62a6d25894954a96b55436b7e8ac9254',
#  '78371365bf9f48658b3ab78f159e2da3',
#  '5845da21b7654828ada452c86f713890',
#  '24fae92db45b4aa19018cdc4d457b62f',
#  'c86ae6327008450f974fcd09d2d67e23',
#  'c84ef18df1eb43998a283f3b57559222',
#  '8dd4e1ecc0ff48f5a2e7c1eb3ba785c9',
#  '23d0d85fd99b40e68d54c4057210ac05',
#  '76e799d2fa6c422db35ccb0f9f73d3c6',
#  '738c2f543f38409c9efd739b562e1992',
#  '8fc76431cb6a49ac891d5b959fed0deb',
#  'a0316f7a13884efe8de78c9f49fe2447',
#  '2a6d91d876c141188e63ac8a916fba81',
#  '924c301f1d134c948fb705932c8346b5',
#  'd63725ff6aaf401e85b6370cf6f8102c',
#  'e9c6b71435b0469697fd50984178c85a',
#  '9a8dd02dcb594fa1a44172ac929c0274',
#  '9f920122def443369db659d9cb0e0bbc',
#  '29de7b57d6be4057869eab0193ce12a9',
#  '88e2ee405e1f4b1393d1e03e4ddc0665',
#  '56322856a8084de3a92ea6ccfed93b89',
#  '81549f9650514b5eb62ecf546c77e28c',
#  '2bcc3179d0494ba8a4f67927db04c424',
#  'b27f20986ecf4ea0b4e7bca1787bb918',
#  'e8e1664ba8dd426aaac4be4da80c3fbc',
#  '445d35cec2294022a7e818b90943c09f',
#  '8dd5d4730b5846fcb0b451728b7bb6f1',
#  'b2966f35dc404a6f809b7a0563c5e101',
#  'ef03dc873dd84bc6bc520987a2e9d7a3',
#  '97ae8758218e4f2d88cc7006e35418a2',
#  'e7a0f16d339b44feaa76cfb385518c9b',
#  '2cc6eba2b0ed4ad3b9f19ad9b31de4b4',
#  '70007883af744093a06d0375475612c2',
#  '015063d425ad40e7b640f8ae239c354f',
#  '50fd6af71df14ab880cf7584e70ad477',
#  'ed4e62abd57446a4ba55833a5f204684',
#  'ccc94b30ac7141bbb7c358635f71c452',
#  '026555a78a194bddb4baa5d7aeb99015',
#  'f3cdf5eba4a544ceae60ed3b701d33ef',
#  '953c8be4f1e24f63b1dce88b9fbb96a1',
#  '1e07d05dcafc4fad9e566d36cacdbc8a',
#  '4c6b966b729d48e19a1cbf47d73fc5bf',
#  '9d5de7016bc244199b1ef74ad994dace',
#  '0154279cc9e14870bcbc9a62e6c4fa5a',
#  '3b80b0ae1120438db670ef65f2cc9b42',
#  'f2433b19694c4a01aa1287d70750279d',
#  '90cbcd09638b46b8ba99e9a287096451',
#  '1a86db525f5e4b4e9bb312b9519f6270',
#  'c8d4744b780d46cebd70cf6c3fc07858',
#  'd2101bebcbed481f93b769787603d558',
#  '6a04c0184930469aacdd1dc6851f5f84',
#  '8f93edf2d09c4d85ac99f992a9e5e2ea',
#  'cdb8cd0ea7924818b2bd28edfcfd3de0',
#  'dd8d269cde09418bb76c4bd9f8723387',
#  'b0875d4aea914e0ea94ade64eca90d4f',
#  'd5ad20d4b4c1423ebcdac1e34b69836c',
#  'a7d06a496c6743da87392e58569aeecb',
#  'c3b1b672af414913ae6d492434f850e8',
#  '05a6466cd06142f5a6c222be16b8919b',
#  'eca6ca32caa844a08f6dd2c0e3d46a2e',
#  'dc1ec484df87466199f93535ee8cf419',
#  '2059fa1e36414b20a729da201e3f9399',
#  '35253538c5a34b20834a7edda47a4c4b',
#  '50b92638e1dc4d52ad58a96253df9039',
#  '69042de192a1407e846080d3d5efa053',
#  'd024e993ca1545ba93e333f7bc1d0260',
#  '9a65f28fba48454d85d65191e72378e2',
#  '5fa533c2c3dd4fe5adaf622a9141fbc8',
#  '9aa26191b1fa4e01a6da88d77693ce50',
#  'feeb2dd26ac84a6baee72cb94474bd5a',
#  '9f81bb8fbd4245f985d3c867b37c6146',
#  'cdaa4a3bc4244fcda1a418c03c88e0b3',
#  '2f4ecd7540bc4438a8b2ed9dbd52b03b',
#  '7f0a1436385d48d4b2fcd4d50f513be1',
#  '3eb6786b0de44031bbef2d48fd983bdd',
#  '15e01f9900f44f298cb6674ee5db7da3',
#  'eaf34d044388455f90daa5e31b86703f',
#  'ecace39346e64ef3b85016ccc5691ef9',
#  'e077d7104e6741a4a950f96078f0e6c6',
#  '4ea3a16559a242919c572d804c433056',
#  '15239293e44d4bcd84c1b44e558b36df',
#  '2aaac952d38e4a62b90a85eb36162ba2',
#  'b7b14b460af940ed89c504df486d8135',
#  'ff14a922e3284e96b79e04e3598f9da5',
#  'fae01b3e86f54c05a45672d4f6cc555e',
#  'e42afafb150b470898b0b1ab974b7d7f',
#  '30a3fbb30c0b49cfbb0bcfea14dda195',
#  '00fad652ea664adb996eb4688efd9b8d',
#  '64322890cefa428e991525d95ad48c36',
#  'c7d4fc6bdea24c958bb768ef0c8c43bb',
#  '68ff55778ef54076a0256102ad26a0e6',
#  'e1c8c9f41f814ad0af0a5c29a84139fb',
#  '37e42e4b72d648c69b49cd83d83e91ff',
#  '4de1f164e898447aa269d2cdc8a6b8fb',
#  '26354a0c2f014919bec0865128f1cd1c',
#  'ff51bfebdc754eaea2dc1efc2debfa9e',
#  'bf827e2437654950a58ddcec025715d7',
#  '3e652889ef9642c594dc5e2f51779689',
#  '2daff0f484524ac0a69ebcf29f50967e',
#  'fd4afa88c0064e5c843ebf6e52aaa7f9',
#  '8d628edf8ab44fdaa01027f668bdc593',
#  '0c5c33ea47644d6f97c0a95d3733d11a',
#  'adc84798650f4181b5ae46f6fd8aec23',
#  'd1f1f4c3249541fda78286ee36923f9c',
#  '9a05adefd3fe416e80d3e5252701833c',
#  '5b09ce09d52949cca5082cd29c68a4ce',
#  'fb026ea074e441cf976e83a7832681c7',
#  '49900bfb0dfb4692be8c846bc96d9072',
#  '4331ac8da6154d1988884d43cc53c00c',
#  '1e5d7b7032be4e458a07504147c6cac8',
#  '6f2764f234494ca8984a0979a4806141',
#  'a9f110fd2f844e4ca7490afe9bb88a24',
#  'ac1b5f80eaf0409e8172bd1c672f5533',
#  '678a7a62aea64053be2ff3ea1721b78e',
#  '5ae89cb78c26485095dd3895d683096c',
#  'a03e351c156646f4a71b171872f7e64c',
#  'ca1065cc140b448f80027d4c7c942717',
#  '15fefb66a5524a7c9382100cbdfe8eca',
#  '7ef2d70a384144dba72cd37259b1b50e',
#  'debb7c79f40346b8b67620c8a5604822',
#  '7e7a642357d24f778de9157d11b59609',
#  '9c85318733b34c07b0a248f330f171ae',
#  'ae9bfaafa4eb4d999247050f217349bc',
#  'b073385a53454087a5c30da8287284ba',
#  '98d95cfb23f04e2f913a87fdaf993042',
#  '5210b706edba41929270c731995e3425',
#  'e499b5cd1cb04a1a97b7da5101f59994',
#  '03fd98dd4bde49b498a45557f9a7ae9c',
#  '4242745eed704418ba8a00e14605fb95',
#  'd724b53f19eb4eb7b7b2bd143ec3c6f3',
#  'f40dba92762b4db8812739aa885d9bfb',
#  'b0fdfe05b3cd435096c3e250eb007fbb',
#  '1734c0955d114830a66c377a43ce9778',
#  'cd0d4ba0d09a4a59bbe29708623456d0',
#  '18b83956a1a548e2bc6524793e606c04',
#  '79f6cbddff0e40c9b9ff0b118fa6a484',
#  '14ada892b0d9464f8de3a30b247db316',
#  'b12f272a46284c54b5f126731998f859',
#  'f2370fce79b148a6abce5a707e0135b4',
#  '8c493afce6104b8486ea65a8fdcc4a20',
#  'c59d9115d0af484b91fc3fcdebade210',
#  '41a82696c54e4ce395de144f51e6fe50',
#  '5e6b4b6caf044c37a70495d9efdfc349',
#  '069f0e89ea3d4b27b5c50dbd88927520',
#  'd8386b2b762b43119a7120743b5fd55b',
#  'b4135869a45f44039196d91e8dc26110',
#  '1a6bacdaec47443bae1f11c6a34c3e6b',
#  '9ab8f7e011074d8ca539baa1b5df5a8d',
#  'd20090672e424d4c83ac09a04aea9a2d',
#  '02c847d901b14ae2818d358f6dec3944',
#  'bc3983ad2c244a0e80226cfd82471a0f',
#  '5d568a36bf8f432dad203cd7c364ac7a',
#  '6ee270bdedcd4dc3b3b5acf6aca292da',
#  'a6e082e4d331400baa0adbcb1122bacc',
#  '711bf6f3ad7f4b3e9865da86a53af5e1',
#  '9ca64b9af6d1487ab4023763d520b843',
#  'e1b15e6b774d42e598b0af19ae0f4da3',
#  '7b3a446ee092413c90517368843d1255',
#  'd9fa5f18faeb4902a066e0bbe67dc1c1',
#  '0b7167dd2dd041a79757bca45096379b',
#  '93ed2d2df07f4d448f3f246fd5ffb3dd',
#  '1983e28b555043f4a109f6e586f31a33',
#  'ea3f881c4f804fe39ad6fd27e6f631bf',
#  '0ecdd17f9c004fe2a12ccc126885c66d',
#  '3eda97e239944533ae55ea9e322c07e6',
#  '32d5f896aade477dbbe06c863247a9e7',
#  '778a8cbfb51746b0a3e7feebda2de519',
#  '0194b7c0e81d4871a1653a7897e5ddbb',
#  '71845e42620f4e10af36084a8b6df492',
#  'bfac6aaa74ef4d10a120ac171b36ad93',
#  '2e04ce416b7c49a8b7b6528064d39215',
#  'e361787a24b24f7dad6dd33642f6900f',
#  '9fb48be4b11446db928e2e3af6cdc24c',
#  'ed3adffa3ea247f38290702e236c543e',
#  '5ff4651004af4ca6a502ebc4d67ed9f1',
#  '454e0119075640fe838a99276633bd1f',
#  '01d7b5864b3a4d46a7407caca860b017',
#  'e55393a1062b4eed8ff21b8b9a98638c',
#  '205f6b27118e42299a5fa39962367a3d',
#  'dbd4af0abc46474789d542bb835c6443',
#  'dc408124032d4ee5851b11e756bc2537',
#  'e4d8a57322e4423ba71b2964b735bdaf',
#  '1243b328962f4a5fa1e52523ad189b9a',
#  'fb8fe599b83548ec81149762a2979fb1',
#  'a2285f14647648079decca75c70d35c4',
#  '9c1d81f9240e49d1bae146da2881696b',
#  '804b06d323294c34a9025030ea59d270',
#  '0cbe2dd7f9f54acca896e60f8df0c1c6',
#  '6a6d09810c234967a9feeee17652f2d1',
#  '54288603eddc40cdadb51b8aa60d5f87',
#  '89c60dd91f894bdab567adf8ba6d280a',
#  '172ee5c2409f4918b977cf7dd50433b3',
#  '598b0275fc86463eb6a7b5556f565399',
#  '592475db99bc4355aab8cb98f0675955',
#  'd20697b1eecd40ed83ec39eb4a39cda8',
#  '93ffc91fe2534faca56ff477b13481ae',
#  '471405a0b35d47b7bc7036b7267eaa2f',
#  '601e0061597e4d0c9a65f259697d64a7',
#  '125f9bb89f6641cd8d35d7cb14547945',
#  'dd64bf8342a9491e91eba1c22e115ad3',
#  'c5d6563b650c4446a7e0e7bb8b67e751',
#  'b22f1736c28b4a008e149d79a66e24a2',
#  '4d38602974d049b0a578d8c25e859118',
#  'dc335461bf9e47c2a3fb3e9951fbfe19',
#  '5cf336d4845a4e1b90b7766d9ce8ebfe',
#  '7dfdbe8dc4fc47b6b00383a4e9921190',
#  '51110833019b420295aa9db550b334db',
#  'de2c7077afd14075b8f9d407380f63f8',
#  '63b57a0df5a54ab0a11662e1b984583a',
#  'c988d72af84c4cd6aaf9f9ece63f6f0e',
#  'e4289e10536e4d16b3556cbddebad0f6',
#  '6dbd9a5e039f4ecba59c7ea637f78c6a',
#  '0cd0e879c09f480faec1976bf1ff1a10',
#  'b0f1d630f0c44fc7b20ea3ea5832bcbb',
#  'ed15c042f2f949beaa0832c8467bd70a',
#  'ab957785d7794bc2b8a2c6074d0e682c',
#  '2a4a54134a6c447f8d2d7541693e6eb3',
#  '5a6d22a0b35b41658ab861eeb7aa6343',
#  'd38dd3dc3e71498098a7636e05c4239a',
#  'a4de5058f76b42979e0e75686d9ca25a',
#  'c216a98c352d414e87a3f989dbb8786c',
#  '44618ba66f6544f6b6ce871a5901042a',
#  '0b96a15152234ac1923cfa55b09c64ad',
#  'd18a2167eb164913ace28da361002826',
#  '6011ae68db6046519f8f842d5deac84e',
#  'ddb9c7fd93624fc881446082cd823a8f',
#  'f84f6a01df664bb4ac17bd34cf517fe0',
#  'cb3da0806a264a16a64890a0d5b47487',
#  '896455afeac64ba5903b82a786d91e00',
#  '47091ec1367c4e74aad4eef18c327657',
#  '557070f789b54af29bd310501709c25f',
#  '09adb0c813944e8ab2e2e87960bbaf91',
#  'c41ecc8e76154093b68ec3b17b7b8ecf',
#  '28d45c7de7c94edc983767cf5d5ab1b8',
#  '2d716973aa52443e926e1509443ddef9',
#  '0ab825fdcdcc424b8193cc7893c31721',
#  '916b157fa61c46a88d95aa1d96fb8645',
#  '4b8629099ab54f57860173513be5b962',
#  'ce09edda12c946b49a0fc53327b0055c',
#  '049b107a68cb45958096809cdeb06ca7',
#  '5b26af79745b409aa32323df59a40944',
#  '8cb74f057e7d46d6b3714bff6ee55f69',
#  '010bda39554c49c79273a6ffc1e41fff',
#  '9024e086f48143cd89ed3a6f89a59541',
#  '1d9dae2ef87c47069bf57613b3636aec',
#  '2bfba768437c4fc4b8316420a65875e6',
#  'e82af7dde8fc4fd3894ed712fff5167b',
#  '9aaaef3583884405afb416e1e7e12b8a',
#  '5eecf20087ad43a2947c84575dcfc407',
#  '2d8e6050250f458591c80c5772743d51',
#  '9a2cc8d82a94455fa8027b8e545d6a0b',
#  '6ace4249daf24ae3a58a552edd073fe2',
#  'b72015c900154da09ddeedef5ac53da0',
#  '5616a9670ae342cfa8dc9c0f21bee026',
#  '739b7bad5b8340a2a2d7ef82c007194d',
#  'e692af0b07534d6c92ec555cd3973510',
#  'afde7cefef5846bb91965c251d669fb8',
#  '02bbcce3f43d498e816b36c2664ac2f1',
#  '914adb9fd5af4259bf0e5b6fa2a179ed',
#  '84f44b9487d44b35aa2a3bed9cbe5436',
#  '3aa694bcc3684bfcbbbb9fd21d58ebf3',
#  '8aa588d65f094a91a5ba072bc19fa7ab',
#  'e345e9f7ce68481192a48423108c2143',
#  'f2094071108d4bed8a3865de5f13a137',
#  'b3e833d1712b4cbfb302e9c548864e33',
#  '9f64a4be389d4d72a71d16921cd8a2a2',
#  'b62457583ef74f76b64532e88d5f320d',
#  '4a3e43d94fbe49d89d59587770d6ca31',
#  '0e95b1f3cfa142d7bd3850e7664e36eb',
#  'fb36ac7b41194974b54115dfc3cce5fe',
#  'e8d63556686b4e57ac312035cee5c3a0',
#  '148d7ae6fc3642a2bf59ee060dae74c3',
#  'ed014741cb62413bbc497b3027cc73ff',
#  '109fd5d15dbf4bff9c83dede405988d7',
#  'a08c20c9a71f4db789789fc19cb567af',
#  '28e626c84d9e4665a324f3d1cf945033',
#  'a2e44e34582349569a0498f300b4daec',
#  '8f97f4a945d64a57a34050caa14d92c9',
#  'c94af95db4124bcb84aca6a6723c24cd',
#  '2f5b2f3abfe84674982310b99d83519c',
#  'bf2f9bbd3b2842f1a4f62d840237f608',
#  '4b544889256940a29b3a43535c6d41dc',
#  'be25e1cd302f474ab37dae98a725e8be',
#  '64a27332598d49359b2ed3a1a52b25ca',
#  '3d23dfd94ecc4297874e61e12c6e5ce7',
#  '6190d15315314c51b7347b8fc38a6493',
#  'f75bf911fbf940e8a2cd5d3b42b6d237',
#  '7eaf1a204412433686d9f80a47973f6c',
#  '40a52b2691f349e193b0070985dd4762',
#  '68ab40ad309346dd95c4756c99649edd',
#  '1e1d4698d4e4497a998e35c379949640',
#  '187ba479bb314b83b47f895cfee9c97f',
#  'c56cba09d6c342a6ad6db47d2a78aedf',
#  'af630eb676124e659d14026893bc3ea8',
#  '7097c4c734644846befe57ec0e9897a9',
#  'f85b3ab7f7fc4b83be7d4ded377ee6c1',
#  '8cb8bb337f334614bd12a1774ace8085',
#  'ef660aaccf3342608a8e905863b4cbcd',
#  '48f9bc9d91ee40ad889060e68b725989',
#  '078026cefaca43ca874f5287752491b7',
#  'e3a7e8e1e0ff4136912b50e31a2f64f1',
#  '7655b2cedc1e4284a4599a010f36cde1',
#  'c979a74f5a5e4b42be2936700fe23719',
#  '52c08a1d00f946b682a5c3f2545eea9e',
#  '7ecbaba773cf4db09af5c2a9635f449c',
#  'bd50c16d68514c8296681cc16e680519',
#  '1efe7d7d934c45f19c178b4f900d7672',
#  '43984227802c48eda091e7b2d955c44a',
#  '8bb0b67c51f54d39aa666a3a302c52de',
#  '2b71242939e14f7da854eb0facc2e7be',
#  'f0bc5419e6d84580922195b374e67084',
#  '560b33dae96e45a8b514b84ef5552582',
#  '01748f3b267948d1ac62fb189479b8c1',
#  'e8d6336394fa43989d8fe1e7942a2541',
#  'fdd1a7d16d2f4143bdd10a9020e9b4ef',
#  'a0465e6d073a413b811b66dff6a7adce',
#  '447f4d75c1324376b0b98f318fe53eda',
#  'eabd4dc9eb3248c7ae29c88d5dd1d72d',
#  '8ea025a54b614479903ea75d9405dff7',
#  '37467114cf9b4072b033be5bdae9cf0f',
#  'c20362f3300f4984a2f1ad58b2ce6b63',
#  '1b394393e6fb474e9ce9c5eb05634978',
#  '6d0b64da6f0f4501ae721a3ce1910a18',
#  '06d0950880394d4a942ed5208a72e2f6',
#  '563c4032a12d486899f1e1fe9cda09ac',
#  '5abcd74ab7db402fad22319f89c84a43',
#  '53faea30420e4e0d9e44f5e5c3acf329',
#  '9f00648760a542798cfa7f097bab635a',
#  'da514b751456435e8f5f39253789a15a',
#  'd2681f6c748a4ddd940fa432b46d32f5',
#  '7f7abcff1fbc4bb5b49c7acdede6ac6f',
#  '8216c13c163f48bc8c1ace74a7830604',
#  '07bd22455b6849aba92defeb1b9ccd0f',
#  '74cf08931ce14bc39119f451b97197ca',
#  'bd9910594fa1480b9c82766f732b24ca',
#  '14bea35fb2f341a0b1fdb00eb25623dc',
#  'e12bbb31ada84bb8b46cc57bc23a0d84',
#  'd16b855723794c9ca69eca4c9af41a97',
#  '094a8ba55a5e4063affda204df13cbf4',
#  '1b437997c3944b61a41682b3074aef4d',
#  '4ff1124a890147aebca8e3a78a8f4e9a',
#  '5450342755724a258fb60dae631f3c39',
#  'ca3f7a19c17246d4a6453a8d91f297fa',
#  'aab99fe2f2af46d9aa134377f1e6cd88',
#  '5234262abd1b487596453eb462020efd',
#  'eb76bb81a0524c319d7a43c586ea1734',
#  'ff0f772b9a2f4de4b92b25d5cf5c1ef6',
#  '0bf79f9dcdec4b8cb1c0f10a2e120719',
#  'f27a21f4ce154e4f999fc0f788d5a5aa',
#  'fbac10327bd04aa39e4aceefc324590d',
#  'cb28c711a3e1446e816e8cc6a1f98033',
#  '2fa6adebe6574452b5b3a89f5321d013',
#  '96d930015e51408daf2bd0518f394588',
#  '64ff96ed44d64a29ac2a3e9a31c14a5e',
#  '5ac42c19b0b040bea4ac606c573166a2',
#  '567922d99f374f2ba14d11621218927c',
#  '237c5c6549574ed99b409667b0ba75cf',
#  '0e06708820a3448fb88edb8c2ae71ec3',
#  '18a4c5ebfd604f6eb6464b07f07f630a',
#  '22e962d9323f4fd9b85465d8eec8d4ae',
#  '98d25fece8904586a0c941bd7a46bd60',
#  '214d5c4a6a2243618b047c05b49fdd2e',
#  'c3d714bd08f344b9a208129e47daca32',
#  'e34c7e4adc9a4b5fa1546ce6eff04f65',
#  '0ed5b93ea14742928efdb90d2035dc5f',
#  '1c1e9cdb3a2a4c5e912d8ec1a8a8d4ee',
#  '174ef16a5f1f4d2499bea34fddf12d05',
#  '26523e6cb9914df1974a25dabfbefa62',
#  '85f6098a4f604c888d01168f1dfb6d60',
#  '20fb2f28fc7b49898b99a16bfb7006a2',
#  '79ab56b13e7b4543ac518b3fc6286916',
#  'f9f67aa1236d4d1b8cbad06b7f62218c',
#  '3a1bc36131cd45789e576d0caa56e742',
#  'ac5a0f7ca3fe4cbeb05807fe05d04f0b',
#  '78de2dc7e8264f98b805d14b3954a596',
#  'ec31b23e55a8439c87367bdfc876ffb4',
#  'efa60ef3ff644ff69fed36d23f8cdf8d',
#  'ba5043a4673149f8b23a0f94050c0343',
#  'f4b2deb1283b409bb8f62c9df8485a03',
#  'f0169e7bcc1f495fa2483e2be6558a70',
#  '6fc236c8a1be49cebefab9220b91039e',
#  '943995fe05ba4b25b36840cd3d4551f1',
#  'f49b66d32a55446b8018418c82b6d217',
#  '87191d50b3b649a2bbc1c6677bc17db4',
#  'd1479b2e66f24470aa03a3ef237d06c6',
#  '1295cb5c01e8426b8d410ae9ccd3fd84',
#  'd83789510c1649b59ed599f4cbb8888e',
#  'a2af2d2da78840eda8cc927b1fdbcd91',
#  'f636db0d60894f9eb2453f9d2e9d9399',
#  '7130414bc1ea40409c744c18d9b78397',
#  '8221c254926b45428e1feb9547bc2e40',
#  '3b4ff689d9064183b12ea3fa70e925c1',
#  '950fa3360ae64ccba7312cbd850d239b',
#  '710acbe9fd114241aef7ff6728bae678',
#  '9d91284ec64f49b0afc7f24412c103f7',
#  '3f0ea6c65b224f65a09fd41d229e3585',
#  '9b48c1f32b34457780d48413a1730126',
#  '265d0e76cac04a058b15bf86d77b7582',
#  '2586e28338ab4d85a86f29a8b1a4f13a',
#  '3d99df397f4646d6ad527889e3f2295d',
#  '84490823b9634b73b5523b66b581d08e',
#  '211bb989b49d443aa6998b49d9d53b84',
#  '3d5c94e723e64df591476e6e943a12f4',
#  'cf05d5d96d8e43f39ea34f350d427224',
#  'b96cebf7ef2a4af08fd7fef879c877c2',
#  '863c244236f14276952a8229ce3cd28b',
#  'f2a7a3fa5bf4489da7b686c7e0e3c2af',
#  '54b441a33d6841a4be57bbb466bd2ae6',
#  '9489f38137c14582b55ff6acd0d36d51',
#  '7bf05626fdff438cae87f2c78097143c',
#  '1b9fe6d866a84f568c0a38724c269fe9',
#  'ec54e812355b43a5bc8fb50e3c95502e',
#  'd38db7175fc247889fae63ccd767025b',
#  '3e6ec1f1a28844d3a3de6286985f1ac8',
#  'c58a2af1b39343fea2cb5cd198071f49',
#  'd056ce8bf25545f4a126791cb6285e63',
#  '74d275736db84ef4bad6fcec8adc5439',
#  '63cae3c9a278456a86318323f9cbddf2',
#  '51cd7a91e5194164994b62c7e936cf4b',
#  '5f57714318d84fa08eb3846887029a77',
#  '792549ee818e4d63bce8590813ac96f0',
#  'f6880090aa914766b7ad548d2298b0bb',
#  '0e3d05e8ae6d42d9b7695441d695f818',
#  'd73ef2adb3e443aa9900173c3b9bb8d3',
#  '44a78ea875b6474c8cf1cacba48bdd2e',
#  '001fb61fa2e743abb8434e8e3c3600af',
#  '57cc34b165b3450e96647d8f74ba7b4f',
#  '381753fb4c06412f96ca43de25efc68c',
#  '9d81db1ec306499cb48a3d1e5bd3b2ba',
#  '686e478d221c4a36aa3a133204a1b71c',
#  '5f2512716baa43ba9cc8549ef0301d64',
#  '7e48f6deb8734d4e9efd301dfc4b05b5',
#  'b92257fa70174b35a8909bf070ea9abc',
#  'd39993b9cd064991afcceb419d979f86',
#  '839d65260f6f4ec7aa4b76ae7849efef',
#  '95dbbb63163544ca8873a833f44798cd',
#  '4f9ad5caabaf491d93dc9319e70c4919',
#  '4bfe2a27589a4aa390b0d0980570b71f',
#  '232d6d8b269f4f25a2224aa0b5bb4be5',
#  '4f5adf3525a846a0b27eba8943b8c38b',
#  '1d95aef172a5459e8f8ec566cec3d248',
#  '384272bad7a94c2193d7b6d85c450136',
#  'ed75b84f4dc54ece9bc4129c39266139',
#  '780dcbde0b0e47079892276b2d9f48e6',
#  'c0e9e5084e50466ebeb72eaa9b4bd92d',
#  'dc923c0fc48541f8a45a34cfe8bc99ff',
#  '0201f3e66e634bc7a0dcde7618d798b4',
#  '08a60cb6978e4edcbae738d27b472340',
#  'ff7ab2f8bf014046a3ad33903e51d028',
#  '35ddc1c573d34cd2a93847be454def01',
#  '3d66069e491d465799f71c69d405245f',
#  'dc14b4b1705b43f1af2f4e4fb52c99c2',
#  '6e0c128515b9456da702b98f5c99f481',
#  '75d7d02689b2461897b910dfc998dddd',
#  'bae78a926ea54fcb8304ce9e6d84e259',
#  'f7a5aaaf4ff240bb825c558c8a4f976c',
#  '0e7094dafa6641b49318ea512762e873',
#  'b76e23169b5f49e1b2d474bbda63ecd6',
#  'f2fd38ff12b445d19943864e5d2a5955',
#  '339d4c9fcbad4fd0b73a4d8a6e98403c',
#  '15d62e3a4cb542278f4feff3beb41a8d',
#  '42fe2b2cdb1f4da38b63b2f297384702',
#  'b84801d3c68444b18911e59352de5074',
#  '86a6a6ccb4e04838a5046140d390fa67',
#  '9aa8e6f1b8e94f1ca2231d78e6e9d425',
#  '12f29aec6da54fbaa769b2eba7110332',
#  'a639695872e34dca9e175b9a738a8861',
#  '6fed87aee4ea4410ac44ffa44aa5e11a',
#  'a5507026776d4217adee83ec419023ac',
#  '035a4374510f435a8eaa7752bbb4c19c',
#  '4fdd5bcfc22e4195807ce85cfab5822c',
#  '182c55bb613d401b9a34b1e9e9a30b2c',
#  '49a14a5d79a846fbbbd92e04cc5b3960',
#  '6ab3880a67384cb18276f602e5d16f73',
#  'ea7710a65b834719af8b91b770da520e',
#  '2bed60f2f13f427ab52b46a5e5b0d337',
#  'c3f64a03d9b040768a1b77faa8edd7bf',
#  '15072beca22647a9a752a05423049526',
#  '1110f1eeb0f44e7fa01ca362dfdb6b74',
#  'bd4b874299f6451189d7c266dd71a60e',
#  '4f879ba187f14dfc968d2b0c2bf5020d',
#  'e16458dbf9344be3821e728db7b23ef8',
#  '59f5df407d6c47389f94e2c7f2d9eed3',
#  '29c960767e97478db83513935dc3c6be',
#  '25df1e2a89dc490ca1d97d7438530ffb',
#  '994552e8972740178dc779d2c0d7e8f7',
#  '5c19297cb6ac456aa84b1fd12d5c8d61',
#  '3003193975e84aed9472332254e9760b',
#  'df67f5426f2843aa899dde917ebe19f1',
#  '781cf05d5ccd403f9ecc533850732bda',
#  '69631da9b261464c9a3520352b65af10',
#  '5f282329cff3428db3501521f98a5465',
#  'd5350504946d4e39bab6b437cdb2447a',
#  '1e441ebc80b8471a867505b452773ed8',
#  '018b9fa2047846fc9065f647277dd025',
#  '75984a4c0b28450fb96ccf04ac4dc81e',
#  'a0a7a7094a554f6ba34a70948a44f7c4',
#  '3d96662e22e148548367a14a6b5f775d',
#  'c1a5c6f6942846a39a4a9abd19451085',
#  '95b6633bbf084f5cb6994de3e2231d46',
#  '034f462741f74d3c94c5364caeba5d2b',
#  'ef612dba075c4163acf4e564973f2899',
#  '95bc80d6d58d42ab820180a83d979191',
#  'dcfeece463b24b84b9569db760d5ff9f',
#  '2c5bd5289c8d4abc81453d7b32d2cdd3',
#  '69bae0f3d30e4e58ae36cc56470b330c',
#  '139b5b77c95148c0ae476dda327a49e3',
#  '8a2f153b7bd14be2b78757c7db2436fc',
#  '2c25aa7dec514c6eaff7aeb9eecc3b73',
#  'e2bf7bc39d7242f19e9d8bbc5c3ccb21',
#  'b821a69313df4bef93dddfb4ad938849',
#  '8cc6d06e9f3d4bebb09552d4af3c67ed',
#  ...]

# %% [markdown]
# ## Retrieval Augmented Generation

# %%
prompt = """What are the various side effects of Elidel?"""

# %% [markdown]
# Using OpenAI API requires providing the API key. Our example demonstrates setting the `OPENAI_API_KEY` using an environmental variable.

# %%
import os
os.environ["OPENAI_API_KEY"] = 'INSERT OPENAI KEY HERE'

# %%
from openai import AsyncOpenAI

openai_client = AsyncOpenAI()

completion = await openai_client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt},
    ]
)
print(completion.choices[0].message.content)
# Out:
# Elidel (pimecrolimus) is a medication used to treat atopic dermatitis (eczema). Although it is generally well-tolerated, some people may experience side effects. The most common side effects of Elidel include:
#
# 1. Burning or stinging sensation at the site of application
# 2. Itching or mild redness of the skin
# 3. Skin infections, cold sores, or minor skin irritations
#
# Less common side effects may include:
#
# 1. Headaches
# 2. Flu-like symptoms
# 3. Allergic reactions, such as hives, rash, or swelling of the face, tongue, or throat
# 4. Eye irritation, such as redness, itching, or watery eyes
#
# It is important to note that Elidel carries a black box warning, indicating that it may increase the risk of skin cancer and lymphoma. However, the incidence is very rare and it is recommended to discuss the potential risks and benefits with a healthcare professional before starting the medication.

# %% [markdown]
# ### Testing out the RAG pipeline
#
# By leveraging the semantic context we provided our model is doing a better job answering the question. Let's enclose the RAG as a function, so we can call it more easily for different prompts.

# %%
import asyncio

async def rag(question: str, n_points: int = 3) -> str:
    results = client.query(
        collection_name="knowledge-base",
        query_text=question,
        limit=n_points,
    )

    context = "\n".join(r.document for r in results)

    metaprompt = f"""
    You are a Pharmacist.
    Answer the following question using the provided context.
    If you can't find the answer, do not pretend you know it, but answer
    'I don't know'.

    Question: {question.strip()}

    Context:
    {context.strip()}

    Answer:
    """

    completion = await openai_client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": metaprompt},
        ],
    )
    return completion.choices[0].message.content

# %% [markdown]
# Now it's easier to ask a broad range of questions.

# %%
print(await rag("Name 2 drugs used to treat Diabetes"))
# Out:
# Onglyza and Janumet are two drugs used to treat diabetes.

# %%
print(await rag( "Which drug should not be used on children?"))
# Out:
# Based on the provided context, it is unclear which specific drug should not be used on children. However, both Elidel and Eucrisa are mentioned in the context as medications that were used on children with severe eczema and have caused negative side effects. It is important to consult with a healthcare professional, such as a pediatrician or pharmacist, before using any medication on children.

# %%
print(await rag("What are the various side effects of Elidel?"))
# Out:
# The various side effects of Elidel, based on the provided context, include fever, headache, muscle stiffness, nasal congestion, numbness in hands and legs, heartburn, discomfort after application, swollen and burning lips, unusual redness and bumps, severe itch, redness, swelling, and heat rash-type bumps on the face.

# %%
print(await rag("What drug can be used to treat a broken jaw?"))
# Out:
# I don't know.

# %%
await rag("To build an NLP API, what should I use?")
# Out:
# "I don't know."

# %% [markdown]
# Our model can now:
#
# 1. Take advantage of the knowledge in our vector datastore.
# 2. Answer, based on the provided context, that it can not provide an answer.
#
# We have just shown a useful mechanism to mitigate the risks of hallucinations in Large Language Models.
